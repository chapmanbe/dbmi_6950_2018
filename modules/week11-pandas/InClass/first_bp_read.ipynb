# %%
# %matplotlib inline

# %%
import pandas as pd
import os

# %%
data = pd.read_csv("/home/jovyan/DATA/TimeSeries/UofUData/data_all.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  VirtualCaseID  VirtualPatientID  AIMS_Patient_Age_Years  \
# 0           1          10349              8114                      50
# 1           2          10349              8114                      50
# 2           3          10349              8114                      50
# 3           4          10349              8114                      50
# 4           5          10349              8114                      50
#
#   AIMS_sex  Numeric_Proced_Code      VirtualDateTime  noninvDIA  noninvMAP  \
# 0        F                99232  1986-01-18 11:38:00        NaN        NaN
# 1        F                99232  1986-01-18 11:39:00        NaN        NaN
# 2        F                99232  1986-01-18 11:40:00         64         77
# 3        F                99232  1986-01-18 11:41:00        NaN        NaN
# 4        F                99232  1986-01-18 11:42:00        NaN        NaN
#
#    noninvSYS  invDIA  invMAP  invSYS
# 0        NaN      40      70      84
# ...

# %%
sumbdata = data.dropna().head()#["invDIA"].plot()

# %%
data[data["VirtualCaseID"]==10349]
# Out:
#      Unnamed: 0  VirtualCaseID  VirtualPatientID  AIMS_Patient_Age_Years  \
# 0             1          10349              8114                      50
# 1             2          10349              8114                      50
# 2             3          10349              8114                      50
# 3             4          10349              8114                      50
# 4             5          10349              8114                      50
# 5             6          10349              8114                      50
# 6             7          10349              8114                      50
# 7             8          10349              8114                      50
# 8             9          10349              8114                      50
# 9            10          10349              8114                      50
# 10           11          10349              8114                      50
# 11           12          10349              8114                      50
# ...

# %%
sumbdata["invSYS"].plot.line()
