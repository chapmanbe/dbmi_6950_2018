# %%
# %matplotlib nbagg

# %%
import os
import pandas as pd
import datetime
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from patsy import dmatrices
import matplotlib.pyplot as plt

# %%
DATADIR = os.path.join(os.path.expanduser("~"), "DATA", "TimeSeries", "EPA")
os.path.exists(DATADIR)
# Out:
# True

# %%
files = os.listdir(DATADIR)
files
# Out:
# ['aqs_data_dictionary.pdf',
#  'San_Diego_2016_PM25.xlsx',
#  'Salt_Lake_2016_PM25.xlsx',
#  'Asthma_SLC.xlsx',
#  'SLC_Weather_2016.xlsx']

# %% [markdown]
# ## Read the air quality data

# %%
slc = pd.read_excel(os.path.join(DATADIR, 'Salt_Lake_2016_PM25.xlsx'))
print(slc.columns)
slc.head()
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Date Local',
#        'Time Local', 'Date GMT', 'Time GMT', 'Sample Measurement',
#        'Units of Measure', 'MDL', 'Uncertainty', 'Qualifier', 'Method Type',
#        'Method Code', 'Method Name', 'State Name', 'County Name',
#        'Date of Last Change'],
#       dtype='object')
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0          49           35      3006           88101    4  40.736389
# 1          49           35      3006           88101    4  40.736389
# 2          49           35      3006           88101    4  40.736389
# 3          49           35      3006           88101    4  40.736389
# 4          49           35      3006           88101    4  40.736389
#
#     Longitude  Datum            Parameter Name Date Local  \
# 0 -111.872222  NAD83  PM2.5 - Local Conditions 2016-01-07
# 1 -111.872222  NAD83  PM2.5 - Local Conditions 2016-01-07
# 2 -111.872222  NAD83  PM2.5 - Local Conditions 2016-01-07
# 3 -111.872222  NAD83  PM2.5 - Local Conditions 2016-01-07
# 4 -111.872222  NAD83  PM2.5 - Local Conditions 2016-01-07
#
#           ...                      Units of Measure MDL Uncertainty  \
# 0         ...           Micrograms/cubic meter (LC)   2         NaN
# 1         ...           Micrograms/cubic meter (LC)   2         NaN
# 2         ...           Micrograms/cubic meter (LC)   2         NaN
# 3         ...           Micrograms/cubic meter (LC)   2         NaN
# 4         ...           Micrograms/cubic meter (LC)   2         NaN
#
#    Qualifier Method Type  Method Code  \
# 0         QX         FEM          184
# 1         QX         FEM          184
# 2         QX         FEM          184
# 3         QX         FEM          184
# 4         QX         FEM          184
#
#                                          Method Name State Name County Name  \
# 0  Thermo Scientific Model 5030 SHARP w/VSCC - Be...       Utah   Salt Lake
# 1  Thermo Scientific Model 5030 SHARP w/VSCC - Be...       Utah   Salt Lake
# 2  Thermo Scientific Model 5030 SHARP w/VSCC - Be...       Utah   Salt Lake
# 3  Thermo Scientific Model 5030 SHARP w/VSCC - Be...       Utah   Salt Lake
# 4  Thermo Scientific Model 5030 SHARP w/VSCC - Be...       Utah   Salt Lake
#
#    Date of Last Change
# 0           2016-04-22
# 1           2016-04-22
# 2           2016-04-22
# 3           2016-04-22
# 4           2016-04-22
#
# [5 rows x 24 columns]

# %%
i = 2
slc.iloc[i:i+10,10:15]["Sample Measurement"].mean()
# Out:
# 17.23

# %%
d1 = slc["Date Local"][0]
t1 = slc["Time Local"][0]

# %%
t1
# Out:
# datetime.time(13, 0)

# %%
print("Date Local type",type(d1),"Time Local type",type(t1))
datetime.datetime.combine(d1.to_pydatetime(), t1)
# Out:
# Date Local type <class 'pandas._libs.tslibs.timestamps.Timestamp'> Time Local type <class 'datetime.time'>
# datetime.datetime(2016, 1, 7, 13, 0)

# %% [markdown]
# ### Comments:
#
# * Dates and times are split into separate columns
# * We have both local time and UTC time

# %% [markdown]
# ## Merging Dates and Time
# * After we have read in the data we could combine the dates and times
#     * Convert pandas Timestamp to datetime
#     * Use ``datetime.combine`` to merge with ``datetime.time``
# * We can also merge these when reading the data by specifying the ``parse_dates`` keyword

# %% [markdown]
# #### Using ``datetime.combine``

# %%
slc.apply(lambda x: datetime.datetime.combine(x["Date Local"],x["Time Local"]), axis=1).head()
# Out:
# 0   2016-01-07 13:00:00
# 1   2016-01-07 14:00:00
# 2   2016-01-07 15:00:00
# 3   2016-01-07 16:00:00
# 4   2016-01-07 17:00:00
# dtype: datetime64[ns]

# %%
sd = pd.read_excel(os.path.join(DATADIR, "San_Diego_2016_PM25.xlsx"))
sd.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           6           73      1011           88101    3  32.725226
# 1           6           73      1011           88101    3  32.725226
# 2           6           73      1011           88101    3  32.725226
# 3           6           73      1011           88101    3  32.725226
# 4           6           73      1011           88101    3  32.725226
#
#     Longitude  Datum            Parameter Name Date Local  \
# 0 -116.365203  WGS84  PM2.5 - Local Conditions 2016-01-01
# 1 -116.365203  WGS84  PM2.5 - Local Conditions 2016-01-01
# 2 -116.365203  WGS84  PM2.5 - Local Conditions 2016-01-01
# 3 -116.365203  WGS84  PM2.5 - Local Conditions 2016-01-01
# 4 -116.365203  WGS84  PM2.5 - Local Conditions 2016-01-01
#
#           ...                      Units of Measure MDL Uncertainty  \
# 0         ...           Micrograms/cubic meter (LC)   5         NaN
# 1         ...           Micrograms/cubic meter (LC)   5         NaN
# 2         ...           Micrograms/cubic meter (LC)   5         NaN
# 3         ...           Micrograms/cubic meter (LC)   5         NaN
# 4         ...           Micrograms/cubic meter (LC)   5         NaN
#
#    Qualifier Method Type  Method Code  \
# 0        NaN         FEM          170
# 1        NaN         FEM          170
# 2        NaN         FEM          170
# 3        NaN         FEM          170
# 4        NaN         FEM          170
#
#                                          Method Name  State Name County Name  \
# 0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  California   San Diego
# 1  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  California   San Diego
# 2  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  California   San Diego
# 3  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  California   San Diego
# 4  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...  California   San Diego
#
#    Date of Last Change
# 0           2016-04-12
# 1           2016-04-12
# 2           2016-04-12
# 3           2016-04-12
# 4           2016-04-12
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Read in weather data

# %%
slc_weather = pd.read_excel(os.path.join(DATADIR, 'SLC_Weather_2016.xlsx'), skiprows=[1])
slc_weather.head()
# 28   4.500000  40.736389 -111.872222           23.881250  2.0          NaN
# 29   4.500000  40.736389 -111.872222            4.185417  2.0          NaN
# ..        ...        ...         ...                 ...  ...          ...
# 91   4.000000  40.656390 -111.926914            4.254167  2.0          NaN
# 92   4.000000  40.656390 -111.926914            5.375000  2.0          NaN
# 93   4.000000  40.656390 -111.926914            2.923611  2.0          NaN
# 94   4.000000  40.656390 -111.926914            2.676389  2.0          NaN
# 95   4.000000  40.656390 -111.926914            2.372222  2.0          NaN
# 96   4.000000  40.656390 -111.926914            3.313889  2.0          NaN
# 97   4.000000  40.656390 -111.926914            4.418056  2.0          NaN
# 98   4.000000  40.656390 -111.926914            3.263889  2.0          NaN
# 99   4.000000  40.656390 -111.926914            1.891667  2.0          NaN
# 100  4.000000  40.656390 -111.926914            1.388889  2.0          NaN
# 101  3.939394  40.649117 -111.931886            2.269697  2.0          NaN
# 102  4.043478  40.663346 -111.922158            3.147826  2.0          NaN
# 103  4.000000  40.656390 -111.926914            3.390278  2.0          NaN
# 104  4.000000  40.633533 -111.942540            3.182143  2.0          NaN
# 105  4.000000  40.656390 -111.926914            2.836111  2.0          NaN
# 106  4.000000  40.656390 -111.926914            1.213889  2.0          NaN
# 107  4.000000  40.656390 -111.926914            1.368056  2.0          NaN
# 108  4.000000  40.656390 -111.926914            1.819444  2.0          NaN
# 109  4.000000  40.656390 -111.926914            2.884722  2.0          NaN
# 110  4.000000  40.656390 -111.926914            3.515278  2.0          NaN
# 111  4.000000  40.656390 -111.926914            3.247222  2.0          NaN
# 112  4.014085  40.658643 -111.925373            6.152113  2.0          NaN
# 113  4.000000  40.656390 -111.926914            3.805556  2.0          NaN
# 114  4.000000  40.656390 -111.926914            1.959722  2.0          NaN
# 115  3.985915  40.655263 -111.927684            2.853521  2.0          NaN
# 116  4.000000  40.656390 -111.926914            3.233333  2.0          NaN
# 117  4.000000  40.656390 -111.926914            2.986111  2.0          NaN
# 118  4.000000  40.656390 -111.926914            1.461111  2.0          NaN
# 119  4.000000  40.656390 -111.926914            1.909722  2.0          NaN
# 120  4.000000  40.656390 -111.926914            2.200000  2.0          NaN
#
#      Method Code
# 0     182.000000
# 1     182.000000
# 2     182.000000
# 3     182.000000
# 4     182.000000
# 5     182.000000
# 6     182.628571
# 7     183.000000
# 8     183.000000
# 9     183.000000
# 10    183.000000
# 11    183.000000
# 12    183.000000
# 13    183.000000
# 14    183.000000
# 15    183.000000
# 16    183.000000
# 17    183.000000
# 18    183.000000
# 19    183.000000
# 20    183.000000
# 21    183.000000
# 22    183.000000
# 23    183.000000
# 24    183.000000
# 25    183.000000
# 26    183.000000
# 27    183.000000
# 28    183.000000
# 29    183.000000
# ..           ...
# 91    182.666667
# 92    182.666667
# 93    182.666667
# 94    182.666667
# 95    182.666667
# 96    182.666667
# 97    182.666667
# 98    182.666667
# 99    182.666667
# 100   182.666667
# 101   182.666667
# 102   182.695652
# 103   182.666667
# 104   182.285714
# 105   182.666667
# 106   182.666667
# 107   182.666667
# 108   182.666667
# 109   182.666667
# 110   182.666667
# 111   182.666667
# 112   182.676056
# 113   182.666667
# 114   182.666667
# 112  2886.763688 -7946.701510               436.8  142          0.0
# 113  2927.260080 -8058.737808               274.0  144          0.0
# 114  2927.260080 -8058.737808               141.1  144          0.0
# 115  2886.523691 -7946.865586               202.6  142          0.0
# 116  2927.260080 -8058.737808               232.8  144          0.0
# 117  2927.260080 -8058.737808               215.0  144          0.0
# 118  2927.260080 -8058.737808               105.2  144          0.0
# 119  2927.260080 -8058.737808               137.5  144          0.0
# 120  2927.260080 -8058.737808               158.4  144          0.0
#
#      Method Code
# 0           4368
# 1           4368
# 2           4368
# 3           4368
# 4           4368
# 5           4368
# 6           6392
# 7           8784
# 8           8784
# 9           8784
# 10          8784
# 11          8784
# 12          8784
# 13          8784
# 14          8784
# 15          8784
# 16          8784
# 17          8784
# 18          8784
# 19          8784
# 20          8784
# 21          8784
# 22          8784
# 23          8784
# 24          8784
# 25          8784
# 26          8784
# 27          8784
# 28          8784
# 29          8784
# ..           ...
# 91         13152
# 92         13152
# 93         13152
# 94         13152
# 95         13152
# 96         13152
# 97         13152
# 98         13152
# 99         13152
# 100        13152
# 101        12056
# 102        12606
# 103        13152
# 104        10208
# 105        13152
# 106        13152
# 107        13152
# 108        13152
# 109        13152
# 110        13152
# 111        13152
# 112        12970
# 113        13152
# 114        13152
# 115        12970
# 116        13152
# 117        13152
# 118        13152
# 119        13152
# 120        13152
#
# [121 rows x 12 columns]

# %% [markdown]
# ### Applying different functions to different columns

# %%
slc_day = slc.groupby(["Date Local", "Site Num"], 
                      as_index=False).aggregate(
                         {'Sample Measurement' : np.mean,
                          'MDL': np.median})
slc_day.head()
# Out:
#   Date Local  Site Num  Sample Measurement  MDL
# 0 2016-01-01      3006           19.208333    2
# 1 2016-01-02      3006           23.558333    2
# 2 2016-01-03      3006           26.504167    2
# 3 2016-01-04      3006           34.120833    2
# 4 2016-01-05      3006           25.291667    2

# %%
slc_day_all = slc_day.merge(slc_weather, 
                            left_on="Date Local", 
                            right_on="Day")
slc_day_all.head()
# Out:
#   Date Local  Site Num  Sample Measurement  MDL        Day  High   Low  \
# 0 2016-01-01      3006           19.208333    2 2016-01-01  21.9     9
# 1 2016-01-02      3006           23.558333    2 2016-01-02    23  10.9
# 2 2016-01-03      3006           26.504167    2 2016-01-03    27    21
# 3 2016-01-04      3006           34.120833    2 2016-01-04    32  21.9
# 4 2016-01-05      3006           25.291667    2 2016-01-05    45    28
#
#   Precip. Snow Snow Depth
# 0       0    0          0
# 1       0    0          0
# 2       0    0          0
# 3       0    0          0
# 4       0    0          0

# %% [markdown]
# ### Rename columns to eliminate spaces

# %%
{c:c.replace(" ", "_") for c in slc_day_all.columns}
# Out:
# {'Date Local': 'Date_Local',
#  'Site Num': 'Site_Num',
#  'Sample Measurement': 'Sample_Measurement',
#  'MDL': 'MDL',
#  'Day': 'Day',
#  'High': 'High',
#  'Low': 'Low',
#  'Precip.': 'Precip.',
#  'Snow': 'Snow',
#  'Snow Depth': 'Snow_Depth'}

# %%
slc_final = slc_day_all.rename(
    columns={c:c.replace(" ", "_") for c in slc_day_all.columns}
)

# %% [markdown]
# ### What would be an interesting plot?
